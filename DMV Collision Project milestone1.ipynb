# %%
#Ashadur Omith
#Project Milestone 1

# %%
import matplotlib.pyplot as plt 
import pandas as pd
import seaborn as sns 

# %matplotlib inline

# %%
dmv = pd.read_csv("rows.csv")
dmv
# Out:
# /Users/ashaduromith/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0        10/30/2020      10:00   BROOKLYN    11215  40.668293 -73.979240
# 1        09/29/2020       5:30        NaN      NaN  40.673107 -73.999590
# 2        09/16/2020      11:00        NaN      NaN        NaN        NaN
# 3        10/09/2020      17:10      BRONX    10468  40.862747 -73.904940
# 4        05/03/2018      16:53   BROOKLYN    11223  40.595753 -73.964676
# ...             ...        ...        ...      ...        ...        ...
# 1760592  07/20/2012      22:15        NaN      NaN  40.869591 -73.820392
# 1760593  07/23/2012      21:00        NaN      NaN        NaN        NaN
# 1760594  07/22/2012      18:05     QUEENS    11372  40.752374 -73.879103
# 1760595  07/21/2012      16:20  MANHATTAN    10005  40.704824 -74.006900
# 1760596  07/23/2012      19:28   BROOKLYN    11209  40.634153 -74.029634
#
#                           LOCATION                    ON STREET NAME  \
# 0           (40.668293, -73.97924)                               NaN
# 1           (40.673107, -73.99959)  BROOKLYN QUEENS EXPRESSWAY
# 2                              NaN  ROCKAWAY BOULEVARD
# 3           (40.862747, -73.90494)  WEST FORDHAM ROAD
# 4          (40.595753, -73.964676)                               NaN
# ...                            ...                               ...
# 1760592  (40.8695913, -73.8203916)                               NaN
# 1760593                        NaN                               NaN
# 1760594  (40.7523742, -73.8791033)  88 STREET
# 1760595  (40.7048242, -74.0068996)  FRONT STREET
# 1760596  (40.6341535, -74.0296338)  RIDGE BOULEVARD
#
#                         CROSS STREET NAME  \
# 0                                     NaN
# 1                                     NaN
# 2                    BROOKVILLE BOULEVARD
# 3                       UNIVERSITY AVENUE
# 4                                     NaN
# ...                                   ...
# 1760592                               NaN
# 1760593                               NaN
# 1760594  35 AVENUE
# 1760595  WALL STREET
# 1760596  72 STREET
#
#                                   OFF STREET NAME  ...  \
# 0        506       6 STREET                        ...
# 1                                             NaN  ...
# 2                                             NaN  ...
# 3                                             NaN  ...
# 4        620       AVENUE V                        ...
# ...                                           ...  ...
# 1760592                                       NaN  ...
# 1760593  FRONT OF 212-02 UION TURNPIKE             ...
# 1760594                                       NaN  ...
# 1760595                                       NaN  ...
# 1760596                                       NaN  ...
#
#           CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 0                                   NaN                            NaN
# 1        Driver Inattention/Distraction                    Unspecified
# 2                           Unspecified                            NaN
# 3                           Unspecified                            NaN
# 4                                   NaN                            NaN
# ...                                 ...                            ...
# 1760592                             NaN                            NaN
# 1760593                Backing Unsafely                            NaN
# 1760594                     Unspecified                            NaN
# 1760595                             NaN                            NaN
# 1760596                     Unspecified                            NaN
#
#          CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  \
# 0                                  NaN                            NaN
# 1                                  NaN                            NaN
# 2                                  NaN                            NaN
# 3                                  NaN                            NaN
# 4                                  NaN                            NaN
# ...                                ...                            ...
# 1760592                            NaN                            NaN
# 1760593                            NaN                            NaN
# 1760594                            NaN                            NaN
# 1760595                            NaN                            NaN
# 1760596                            NaN                            NaN
#
#          COLLISION_ID                  VEHICLE TYPE CODE 1  \
# 0             4362870                            Ambulance
# 1             4355070  Station Wagon/Sport Utility Vehicle
# 2             4348585                                Sedan
# 3             4356755                                Sedan
# 4             3894635                                Sedan
# ...               ...                                  ...
# 1760592       2912166                    PASSENGER VEHICLE
# 1760593        259542        SPORT UTILITY / STATION WAGON
# 1760594        279816                    PASSENGER VEHICLE
# 1760595           214                    PASSENGER VEHICLE
# 1760596        140923                    PASSENGER VEHICLE
#
#          VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4  \
# 0                        NaN                  NaN                 NaN
# 1                      Sedan                Sedan                 NaN
# 2                      Sedan                  NaN                 NaN
# 3                      Sedan                  NaN                 NaN
# 4                        NaN                  NaN                 NaN
# ...                      ...                  ...                 ...
# 1760592                  NaN                  NaN                 NaN
# 1760593    PASSENGER VEHICLE                  NaN                 NaN
# 1760594              UNKNOWN                  NaN                 NaN
# 1760595                  NaN                  NaN                 NaN
# 1760596       LIVERY VEHICLE                  NaN                 NaN
#
#         VEHICLE TYPE CODE 5
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 1760592                 NaN
# 1760593                 NaN
# 1760594                 NaN
# 1760595                 NaN
# 1760596                 NaN
#
# [1760597 rows x 29 columns]

# %%
dmv.dtypes
# Out:
# CRASH DATE                        object
# CRASH TIME                        object
# BOROUGH                           object
# ZIP CODE                          object
# LATITUDE                         float64
# LONGITUDE                        float64
# LOCATION                          object
# ON STREET NAME                    object
# CROSS STREET NAME                 object
# OFF STREET NAME                   object
# NUMBER OF PERSONS INJURED        float64
# NUMBER OF PERSONS KILLED         float64
# NUMBER OF PEDESTRIANS INJURED      int64
# NUMBER OF PEDESTRIANS KILLED       int64
# NUMBER OF CYCLIST INJURED          int64
# NUMBER OF CYCLIST KILLED           int64
# NUMBER OF MOTORIST INJURED         int64
# NUMBER OF MOTORIST KILLED          int64
# CONTRIBUTING FACTOR VEHICLE 1     object
# CONTRIBUTING FACTOR VEHICLE 2     object
# CONTRIBUTING FACTOR VEHICLE 3     object
# CONTRIBUTING FACTOR VEHICLE 4     object
# CONTRIBUTING FACTOR VEHICLE 5     object
# COLLISION_ID                       int64
# VEHICLE TYPE CODE 1               object
# VEHICLE TYPE CODE 2               object
# VEHICLE TYPE CODE 3               object
# VEHICLE TYPE CODE 4               object
# VEHICLE TYPE CODE 5               object
# dtype: object

# %%
dmv.columns = [c.replace(' ', '_') for c in dmv.columns]

# %%
del dmv["CONTRIBUTING_FACTOR_VEHICLE_3"]
del dmv["CONTRIBUTING_FACTOR_VEHICLE_4"]
del dmv["CONTRIBUTING_FACTOR_VEHICLE_5"]

# %%
dmv
# Out:
#          CRASH_DATE CRASH_TIME    BOROUGH ZIP_CODE   LATITUDE  LONGITUDE  \
# 0        10/30/2020      10:00   BROOKLYN    11215  40.668293 -73.979240
# 1        09/29/2020       5:30        NaN      NaN  40.673107 -73.999590
# 2        09/16/2020      11:00        NaN      NaN        NaN        NaN
# 3        10/09/2020      17:10      BRONX    10468  40.862747 -73.904940
# 4        05/03/2018      16:53   BROOKLYN    11223  40.595753 -73.964676
# ...             ...        ...        ...      ...        ...        ...
# 1760592  07/20/2012      22:15        NaN      NaN  40.869591 -73.820392
# 1760593  07/23/2012      21:00        NaN      NaN        NaN        NaN
# 1760594  07/22/2012      18:05     QUEENS    11372  40.752374 -73.879103
# 1760595  07/21/2012      16:20  MANHATTAN    10005  40.704824 -74.006900
# 1760596  07/23/2012      19:28   BROOKLYN    11209  40.634153 -74.029634
#
#                           LOCATION                    ON_STREET_NAME  \
# 0           (40.668293, -73.97924)                               NaN
# 1           (40.673107, -73.99959)  BROOKLYN QUEENS EXPRESSWAY
# 2                              NaN  ROCKAWAY BOULEVARD
# 3           (40.862747, -73.90494)  WEST FORDHAM ROAD
# 4          (40.595753, -73.964676)                               NaN
# ...                            ...                               ...
# 1760592  (40.8695913, -73.8203916)                               NaN
# 1760593                        NaN                               NaN
# 1760594  (40.7523742, -73.8791033)  88 STREET
# 1760595  (40.7048242, -74.0068996)  FRONT STREET
# 1760596  (40.6341535, -74.0296338)  RIDGE BOULEVARD
#
#                         CROSS_STREET_NAME  \
# 0                                     NaN
# 1                                     NaN
# 2                    BROOKVILLE BOULEVARD
# 3                       UNIVERSITY AVENUE
# 4                                     NaN
# ...                                   ...
# 1760592                               NaN
# 1760593                               NaN
# 1760594  35 AVENUE
# 1760595  WALL STREET
# 1760596  72 STREET
#
#                                   OFF_STREET_NAME  ...  \
# 0        506       6 STREET                        ...
# 1                                             NaN  ...
# 2                                             NaN  ...
# 3                                             NaN  ...
# 4        620       AVENUE V                        ...
# ...                                           ...  ...
# 1760592                                       NaN  ...
# 1760593  FRONT OF 212-02 UION TURNPIKE             ...
# 1760594                                       NaN  ...
# 1760595                                       NaN  ...
# 1760596                                       NaN  ...
#
#          NUMBER_OF_MOTORIST_INJURED  NUMBER_OF_MOTORIST_KILLED  \
# 0                                 0                          0
# 1                                 2                          0
# 2                                 1                          0
# 3                                 0                          0
# 4                                 0                          0
# ...                             ...                        ...
# 1760592                           0                          0
# 1760593                           0                          0
# 1760594                           1                          0
# 1760595                           0                          0
# 1760596                           0                          0
#
#          CONTRIBUTING_FACTOR_VEHICLE_1   CONTRIBUTING_FACTOR_VEHICLE_2  \
# 0                    Oversized Vehicle                             NaN
# 1                      Other Vehicular  Driver Inattention/Distraction
# 2                 Unsafe Lane Changing                     Unspecified
# 3        Failure to Yield Right-of-Way                     Unspecified
# 4                          Unspecified                             NaN
# ...                                ...                             ...
# 1760592              Pavement Slippery                             NaN
# 1760593               Backing Unsafely                Backing Unsafely
# 1760594                    Unspecified                     Unspecified
# 1760595                    Unspecified                             NaN
# 1760596                    Unspecified                     Unspecified
#
#          COLLISION_ID                  VEHICLE_TYPE_CODE_1  \
# 0             4362870                            Ambulance
# 1             4355070  Station Wagon/Sport Utility Vehicle
# 2             4348585                                Sedan
# 3             4356755                                Sedan
# 4             3894635                                Sedan
# ...               ...                                  ...
# 1760592       2912166                    PASSENGER VEHICLE
# 1760593        259542        SPORT UTILITY / STATION WAGON
# 1760594        279816                    PASSENGER VEHICLE
# 1760595           214                    PASSENGER VEHICLE
# 1760596        140923                    PASSENGER VEHICLE
#
#          VEHICLE_TYPE_CODE_2  VEHICLE_TYPE_CODE_3 VEHICLE_TYPE_CODE_4  \
# 0                        NaN                  NaN                 NaN
# 1                      Sedan                Sedan                 NaN
# 2                      Sedan                  NaN                 NaN
# 3                      Sedan                  NaN                 NaN
# 4                        NaN                  NaN                 NaN
# ...                      ...                  ...                 ...
# 1760592                  NaN                  NaN                 NaN
# 1760593    PASSENGER VEHICLE                  NaN                 NaN
# 1760594              UNKNOWN                  NaN                 NaN
# 1760595                  NaN                  NaN                 NaN
# 1760596       LIVERY VEHICLE                  NaN                 NaN
#
#         VEHICLE_TYPE_CODE_5
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 1760592                 NaN
# 1760593                 NaN
# 1760594                 NaN
# 1760595                 NaN
# 1760596                 NaN
#
# [1760597 rows x 26 columns]

# %%
dmv["CRASH_DATE"] = pd.to_datetime(dmv["CRASH_DATE"])
dmv["CRASH_TIME"] = pd.to_datetime(dmv["CRASH_TIME"])

# %%
del dmv["OFF_STREET_NAME"]
del dmv["CONTRIBUTING_FACTOR_VEHICLE_2"]
del dmv["VEHICLE_TYPE_CODE_2"]
del dmv["VEHICLE_TYPE_CODE_3"]

del dmv["VEHICLE_TYPE_CODE_4"]
del dmv["VEHICLE_TYPE_CODE_5"]

# %%
dmv_cleaned = dmv.dropna()

# %%
dmv_cleaned.dtypes
# Out:
# CRASH_DATE                       datetime64[ns]
# CRASH_TIME                       datetime64[ns]
# BOROUGH                                  object
# ZIP_CODE                                 object
# LATITUDE                                float64
# LONGITUDE                               float64
# LOCATION                                 object
# ON_STREET_NAME                           object
# CROSS_STREET_NAME                        object
# NUMBER_OF_PERSONS_INJURED               float64
# NUMBER_OF_PERSONS_KILLED                float64
# NUMBER_OF_PEDESTRIANS_INJURED             int64
# NUMBER_OF_PEDESTRIANS_KILLED              int64
# NUMBER_OF_CYCLIST_INJURED                 int64
# NUMBER_OF_CYCLIST_KILLED                  int64
# NUMBER_OF_MOTORIST_INJURED                int64
# NUMBER_OF_MOTORIST_KILLED                 int64
# CONTRIBUTING_FACTOR_VEHICLE_1            object
# COLLISION_ID                              int64
# VEHICLE_TYPE_CODE_1                      object
# dtype: object

# %%
dmv_cleaned["year"] = dmv_cleaned["CRASH_DATE"].dt.year
dmv_cleaned["month"] = dmv_cleaned["CRASH_DATE"].dt.month_name()
# Out:
# <ipython-input-12-590249247be3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dmv_cleaned["year"] = dmv_cleaned["CRASH_DATE"].dt.year
# <ipython-input-12-590249247be3>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dmv_cleaned["month"] = dmv_cleaned["CRASH_DATE"].dt.month_name()

# %%
dmv_cleaned["hour"]= pd.to_datetime(dmv_cleaned["CRASH_TIME"]).dt.hour
# Out:
# <ipython-input-13-56a2a5fb6409>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dmv_cleaned["hour"]= pd.to_datetime(dmv_cleaned["CRASH_TIME"]).dt.hour

# %%
dmv_cleaned.head(20)
# Out:
#    CRASH_DATE          CRASH_TIME        BOROUGH ZIP_CODE   LATITUDE  \
# 3  2020-10-09 2021-03-15 17:10:00          BRONX    10468  40.862747
# 8  2018-05-01 2021-03-15 20:50:00       BROOKLYN    11236  40.632260
# 14 2020-09-21 2021-03-15 22:13:00          BRONX    10473  40.827084
# 16 2020-10-31 2021-03-15 12:09:00         QUEENS    11385  40.705590
# 18 2020-10-06 2021-03-15 19:05:00         QUEENS    11372  40.755070
# 19 2018-05-01 2021-03-15 15:00:00       BROOKLYN    11204  40.607765
# 20 2020-10-14 2021-03-15 12:55:00      MANHATTAN    10001  40.746037
# 21 2020-10-01 2021-03-15 16:30:00         QUEENS    11101  40.755234
# 27 2020-10-22 2021-03-15 17:45:00       BROOKLYN    11212  40.656210
# 30 2020-10-01 2021-03-15 15:15:00       BROOKLYN    11232  40.654957
# 32 2018-05-03 2021-03-15 18:10:00      MANHATTAN    10003  40.733524
# 35 2020-09-27 2021-03-15 18:15:00         QUEENS    11101  40.739273
# 36 2018-05-02 2021-03-15 09:00:00          BRONX    10465  40.828125
# 37 2020-09-22 2021-03-15 09:00:00       BROOKLYN    11211  40.716805
# 41 2020-10-20 2021-03-15 11:20:00  STATEN ISLAND    10308  40.537700
# 42 2020-09-18 2021-03-15 16:30:00       BROOKLYN    11219  40.623680
# 43 2018-05-02 2021-03-15 08:00:00      MANHATTAN    10016  40.745796
# 44 2020-10-24 2021-03-15 19:27:00       BROOKLYN    11218  40.640760
# 45 2020-10-04 2021-03-15 22:25:00       BROOKLYN    11206  40.699790
# 47 2018-05-02 2021-03-15 10:00:00         QUEENS    11413  40.659420
#
#     LONGITUDE                 LOCATION                    ON_STREET_NAME  \
# 3  -73.904940   (40.862747, -73.90494)  WEST FORDHAM ROAD
# 8  -73.900880    (40.63226, -73.90088)  AVENUE M
# 14 -73.849915  (40.827084, -73.849915)  BRUCKNER EXPRESSWAY
# 16 -73.865990    (40.70559, -73.86599)  83 STREET
# 18 -73.890020    (40.75507, -73.89002)  77 STREET
# 19 -73.982550   (40.607765, -73.98255)  AVENUE P
# 20 -73.990524  (40.746037, -73.990524)  AVENUE OF THE AMERICAS
# 21 -73.941246  (40.755234, -73.941246)  21 STREET
# 27 -73.914665   (40.65621, -73.914665)  ROCKAWAY PARKWAY
# 30 -74.007034  (40.654957, -74.007034)  37 STREET
# 32 -73.989876  (40.733524, -73.989876)  4 AVENUE
# 35 -73.933716  (40.739273, -73.933716)  HUNTERS POINT AVENUE
# 36 -73.841050   (40.828125, -73.84105)  BRUSH AVENUE
# 37 -73.943060   (40.716805, -73.94306)  HUMBOLDT STREET
# 41 -74.150020     (40.5377, -74.15002)  HYLAN BOULEVARD
# 42 -73.997720    (40.62368, -73.99772)  65 STREET
# 43 -73.982285  (40.745796, -73.982285)  PARK AVENUE
# 44 -73.975020    (40.64076, -73.97502)  AVENUE C
# 45 -73.950096   (40.69979, -73.950096)  FLUSHING AVENUE
# 47 -73.761116   (40.65942, -73.761116)  147 AVENUE
#
#         CROSS_STREET_NAME  NUMBER_OF_PERSONS_INJURED  ...  \
# 3       UNIVERSITY AVENUE                        0.0  ...
# 8          EAST 87 STREET                        1.0  ...
# 14     CASTLE HILL AVENUE                        0.0  ...
# 16              78 AVENUE                        0.0  ...
# 18     NORTHERN BOULEVARD                        1.0  ...
# 19          WEST 9 STREET                        0.0  ...
# 20         WEST 28 STREET                        0.0  ...
# 21              40 AVENUE                        1.0  ...
# 27          CHURCH AVENUE                        1.0  ...
# 30               3 AVENUE                        0.0  ...
# 32         EAST 13 STREET                        0.0  ...
# 35               32 PLACE                        0.0  ...
# 36     BRUCKNER BOULEVARD                        0.0  ...
# 37         JACKSON STREET                        0.0  ...
# 41       ARMSTRONG AVENUE                        1.0  ...
# 42     NEW UTRECHT AVENUE                        0.0  ...
# 43         EAST 32 STREET                        1.0  ...
# 44          EAST 5 STREET                        1.0  ...
# 45           MARCY AVENUE                        0.0  ...
# 47  SPRINGFIELD BOULEVARD                        1.0  ...
#
#     NUMBER_OF_CYCLIST_INJURED  NUMBER_OF_CYCLIST_KILLED  \
# 3                           0                         0
# 8                           1                         0
# 14                          0                         0
# 16                          0                         0
# 18                          0                         0
# 19                          0                         0
# 20                          0                         0
# 21                          0                         0
# 27                          0                         0
# 30                          0                         0
# 32                          0                         0
# 35                          0                         0
# 36                          0                         0
# 37                          0                         0
# 41                          0                         0
# 42                          0                         0
# 43                          0                         0
# 44                          1                         0
# 45                          0                         0
# 47                          0                         0
#
#     NUMBER_OF_MOTORIST_INJURED  NUMBER_OF_MOTORIST_KILLED  \
# 3                            0                          0
# 8                            0                          0
# 14                           0                          0
# 16                           0                          0
# 18                           1                          0
# 19                           0                          0
# 20                           0                          0
# 21                           0                          0
# 27                           1                          0
# 30                           0                          0
# 32                           0                          0
# 35                           0                          0
# 36                           0                          0
# 37                           0                          0
# 41                           0                          0
# 42                           0                          0
# 43                           0                          0
# 44                           0                          0
# 45                           0                          0
# 47                           1                          0
#
#      CONTRIBUTING_FACTOR_VEHICLE_1  COLLISION_ID  \
# 3    Failure to Yield Right-of-Way       4356755
# 8                      Unspecified       3891730
# 14                     Unspecified       4351554
# 16                     Unspecified       4364491
# 18                Brakes Defective       4355416
# 19  Driver Inattention/Distraction       3892952
# 20  Passing or Lane Usage Improper       4357778
# 21  Driver Inattention/Distraction       4354304
# 27  Driver Inattention/Distraction       4360475
# 30                     Unspecified       4353922
# 32  Driver Inattention/Distraction       3893304
# 35  Driver Inattention/Distraction       4352390
# 36  Driver Inattention/Distraction       3892448
# 37   Failure to Yield Right-of-Way       4350724
# 41   Failure to Yield Right-of-Way       4360244
# 42  Driver Inattention/Distraction       4349283
# 43  Driver Inattention/Distraction       3893231
# 44                     Unspecified       4361119
# 45     Traffic Control Disregarded       4355265
# 47                Brakes Defective       3892565
#
#                     VEHICLE_TYPE_CODE_1  year      month hour
# 3                                 Sedan  2020    October   17
# 8                                 Sedan  2018        May   20
# 14                                Sedan  2020  September   22
# 16                                Sedan  2020    October   12
# 18                                Sedan  2020    October   19
# 19                                Sedan  2018        May   15
# 20                                  Bus  2020    October   12
# 21                        Pick-up Truck  2020    October   16
# 27                                Sedan  2020    October   17
# 30                                Sedan  2020    October   15
# 32                                 Taxi  2018        May   18
# 35                                Sedan  2020  September   18
# 36                                Sedan  2018        May    9
# 37                                Sedan  2020  September    9
# 41                        Pick-up Truck  2020    October   11
# 42                                Sedan  2020  September   16
# 43  Station Wagon/Sport Utility Vehicle  2018        May    8
# 44                                Sedan  2020    October   19
# 45  Station Wagon/Sport Utility Vehicle  2020    October   22
# 47                                Sedan  2018        May   10
#
# [20 rows x 23 columns]

# %%
dmv_cleaned.groupby("year").count().plot(kind = "line", legend = False)
plt.title("Accident Rates In New York City")
plt.xlabel("Year")
plt.ylabel("Collision Reports")
# Out:
# Text(0, 0.5, 'Collision Reports')

# %%
#Above is a clear representation of the accident numbers vs years

# %%
dmv_cleaned.groupby("month").count().plot(kind="bar", legend = False, color = "black")
plt.title("Collisions by Month")
plt.xlabel("Month")
plt.ylabel("Collision Reports")
# Out:
# Text(0, 0.5, 'Collision Reports')

# %%
#From this plot, i am observing that accidents dont really vary much by the seasons because july has higher rates than january. And january has higher incidents than April.

# %%
dmv_cleaned.groupby("hour").count().plot(kind="bar", legend = False, color = "blue")
plt.title("Collisions by Time")
plt.xlabel("Time")
plt.ylabel("Collision Reports")
# Out:
# Text(0, 0.5, 'Collision Reports')

# %%
#Looking at the distribution of incidents per hour, it is evident that the most accidents occur at 5PM, the time when everybody in the city is rushing home

# %%
dmv_cleaned.groupby("BOROUGH").count().plot(kind="bar", color = "green", legend = False)
plt.title("Collisions by Borough")
plt.xlabel("Borough")
plt.ylabel("Collision Reports")
# Out:
# Text(0, 0.5, 'Collision Reports')

# %%
#In this graph, we can see all the total incidents per Borough.

# %%
dmv_cleaned["NUMBER_OF_PERSONS_KILLED"].sum()
# Out:
# 1253.0

# %%
dmv_cleaned["NUMBER_OF_PERSONS_INJURED"].sum()
# Out:
# 267389.0

# %%
yearDeath = dmv_cleaned.groupby(dmv_cleaned["year"]).sum()["NUMBER_OF_PERSONS_KILLED"]
yearDeath.plot(kind = "bar")

plt.title("Car Collision Death Reports")
plt.xlabel("Year")
plt.ylabel("Number of People")
# Out:
# Text(0, 0.5, 'Number of People')

# %%
dmv_grouped_year = dmv_cleaned.groupby(dmv_cleaned["year"]).sum()

# %%
dmv_grouped_year[["NUMBER_OF_PERSONS_KILLED","NUMBER_OF_PERSONS_INJURED"]].plot(kind = "bar")
plt.title("People Injured vs. Killed in Collision")
plt.xlabel("Year")
plt.ylabel("Collision Reports")
# Out:
# Text(0, 0.5, 'Collision Reports')

# %%
# By looking at this chart, i can tell that in the accidents reported people were mostly injured instead of rather killed
